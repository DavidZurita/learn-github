# %% [markdown]
# # SISD

# %%
import numpy as np
import time

# Creamos dos arrays grandes
a = np.random.rand(10000)
b = np.random.rand(10000)
c = np.empty(10000)

start = time.time()
for i in range(10000):
    c[i] = a[i] + b[i]
end = time.time()

print("Tiempo con bucle for:", end - start, "segundos")
# Out:
# Tiempo con bucle for: 0.0040395259857177734 segundos

# %% [markdown]
# # SIMD

# %%
start = time.time()
c = a + b  # Esta operación se realiza en paralelo internamente
end = time.time()

print("Tiempo con NumPy vectorizado:", end - start, "segundos")
# Out:
# Tiempo con NumPy vectorizado: 0.0 segundos

# %% [markdown]
# # Tratamiento de Datos
# ## Primeros pasos

# %%
# Instalamos las librerías necesarias
# %pip install pandas
# %pip install matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas) (2025.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.20 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\david\appdata\local\packages\pythonsoftwarefoundation.python.3.8_qbz5n2kfra8p0\localcache\local-packages\python38\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Creamos un conjunto de datos simple con algunos problemas comunes
data = {
    'ip_origen': ['192.168.1.1', '10.0.0.1', None, '172.16.0.1', '192.168.1.1'],
    'puerto': [80, 443, 22, np.nan, 80],
    'protocolo': ['HTTP', 'https', 'SSH', 'http', None],
    'intentos_acceso': [5, 10, None, 7, 5],
    'timestamp': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-01'],
    'exito': [False, True, False, True, False]
}

# Creamos un DataFrame de pandas
df = pd.DataFrame(data)

print("DataFrame original:")
print(df)
print("\n")
# Out:
# DataFrame original:
#      ip_origen  puerto protocolo  intentos_acceso   timestamp  exito
# 0  192.168.1.1    80.0      HTTP              5.0  2023-01-01  False
# 1     10.0.0.1   443.0     https             10.0  2023-01-01   True
# 2         None    22.0       SSH              NaN  2023-01-02  False
# 3   172.16.0.1     NaN      http              7.0  2023-01-03   True
# 4  192.168.1.1    80.0      None              5.0  2023-01-01  False

# %%
# 1. Vemos información básica del DataFrame
print("Información básica del DataFrame:")
print(df.info())
print("\n")
# Out:
# Información básica del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ip_origen        4 non-null      object
#  1   puerto           4 non-null      float64
#  2   protocolo        4 non-null      object
#  3   intentos_acceso  4 non-null      float64
#  4   timestamp        5 non-null      object
#  5   exito            5 non-null      bool
# dtypes: bool(1), float64(2), object(3)
# memory usage: 333.0+ bytes
# None

# %%
# 2. Vemos estadísticas descriptivas
print("Estadísticas descriptivas:")
print(df.describe())
print("\n")
# Out:
# Estadísticas descriptivas:
#            puerto  intentos_acceso
# count    4.000000         4.000000
# mean   156.250000         6.750000
# std    193.112014         2.362908
# min     22.000000         5.000000
# 25%     65.500000         5.000000
# 50%     80.000000         6.000000
# 75%    170.750000         7.750000
# max    443.000000        10.000000

# %%
# 3. Verificamos valores nulos
print("Valores nulos por columna:")
print(df.isnull().sum())
print("\n")
# Out:
# Valores nulos por columna:
# ip_origen          1
# puerto             1
# protocolo          1
# intentos_acceso    1
# timestamp          0
# exito              0
# dtype: int64
